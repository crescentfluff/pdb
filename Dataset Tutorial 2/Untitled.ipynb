# %%
import pandas as pd
labels = pd.read_csv('labels.txt', header=None, delimiter=r"\s+", usecols=[1])
labels.head(39)
# Out:
#              1
# 0          Q-E
# 1         ZN-E
# 2         PH-E
# 3        DBO-E
# 4        DQO-E
# 5         SS-E
# 6        SSV-E
# 7        SED-E
# 8       COND-E
# 9         PH-P
# 10       DBO-P
# 11        SS-P
# 12       SSV-P
# 13       SED-P
# 14      COND-P
# 15        PH-D
# 16       DBO-D
# 17       DQO-D
# 18        SS-D
# 19       SSV-D
# 20       SED-D
# 21      COND-D
# 22        PH-S
# 23       DBO-S
# 24       DQO-S
# 25        SS-S
# 26       SSV-S
# 27       SED-S
# 28      COND-S
# 29    RD-DBO-P
# 30     RD-SS-P
# 31    RD-SED-P
# 32    RD-DBO-S
# 33    RD-DQO-S
# 34    RD-DBO-G
# 35    RD-DQO-G
# 36     RD-SS-G
# 37    RD-SED-G
# 38  prediction

# %%
labels.shape
# Out:
# (38, 1)

# %%
water = pd.read_csv('water-treatment.csv', names=labels)
water.shape
# Out:
# /srv/conda/lib/python3.6/site-packages/pandas/io/parsers.py:678: UserWarning: Duplicate names specified. This will raise an error in the future.
#   return _read(filepath_or_buffer, kwds)
# (527, 1)

# %%
water.replace(['?'], 0)
# Out:
#                                                                                                                                                                                        1
# D-1/3/90   44101 1.50 7.8 ?   407 166 66.3 4.5 2110 7.9 ?   228 70.2 5.5 2120 7.9 ?   280 94  72.3 0.3 2010 7.3 ?   84  21  81.0 0.02 2000 ?    58.8 95.5 ?    70.0 ?    79.4 87.3  99.6
# D-2/3/90   39024 3.00 7.7 ?   443 214 69.2 6.5 2660 7.7 ?   244 75.4 7.7 2570 7.6 ?   474 96  79.2 0.4 2700 7.5 ?   91  17  94.1 0.00 2590 ?    60.7 94.8 ?    80.8 ?    79.5 92.1   100
# D-4/3/90   32229 5.00 7.6 ?   528 186 69.9 3.4 1666 7.7 ?   220 72.7 4.5 1594 7.7 ?   272 92  78.3 0.2 1742 7.6 ?   128 21  81   0.05 1888 ?    58.2 95.6 ?    52.9 ?    75.8 88.7  98.5
# D-5/3/90   35023 3.50 7.9 205 588 192 65.6 4.5 2430 7.8 236 268 73.1 8.5 2280 7.8 158 376 96  77.1 0.4 2060 7.6 20  104 20  96.7 0.00 1840 33.1 64.2 95.3 87.3 72.3 90.2 82.3 89.6   100
# ...

# %%
water.dtypes
# Out:
# 0      object
# 1      object
# 2      object
# 3     float64
# 4      object
# 5      object
# 6      object
# 7      object
# 8      object
# 9       int64
# 10    float64
# 11     object
# 12      int64
# 13     object
# 14     object
# 15      int64
# 16    float64
# 17     object
# 18     object
# 19     object
# 20     object
# 21     object
# 22      int64
# 23     object
# 24     object
# 25     object
# 26     object
# 27     object
# 28     object
# 29     object
# 30     object
# 31     object
# 32     object
# 33     object
# 34     object
# 35     object
# 36     object
# 37     object
# 38     object
# dtype: object
