# %%
import pandas as pd
import matplotlib.pyplot as plot
import random as rd
import math
insr = pd.read_csv('insurance.csv')
insr.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
insr2 = insr
insr2['sex'] = insr2['sex'].astype('category')
insr2['smoker'] = insr2['smoker'].astype('category')
insr2['region'] = insr2['region'].astype('category')

col = insr2.select_dtypes('category').columns
insr2[col] = insr2[col].apply(lambda x : x.cat.codes)

# %%
insr2.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
insr2.sample(15)
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 653    45    0  36.300         2       0       2   8527.53200
# 1122   53    0  36.860         3       1       1  46661.44240
# 372    42    0  33.155         1       0       0   7639.41745
# 1120   23    0  31.400         0       1       3  34166.27300
# 598    43    1  32.600         2       0       3   7441.50100
# 1285   47    0  24.320         0       0       0   8534.67180
# 130    59    0  26.505         0       0       0  12815.44495
# 276    19    1  20.615         2       0       1   2803.69785
# 1167   29    0  24.600         2       0       3   4529.47700
# 210    20    1  33.000         1       0       3   1980.07000
# 946    42    1  35.800         2       0       3   7160.09400
# 221    53    0  33.250         0       0       0  10564.88450
# 176    38    1  27.835         2       0       1   6455.86265
# 464    19    1  25.175         0       0       1   1632.03625
# ...

# %%
insr2.to_csv('insurance_modif.csv', sep=",")

# %%
insr2.plot(x='age', y='charges', kind='scatter')
plot.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
insr2.plot(x='bmi', y='charges', kind='scatter')
plot.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
corcol = insr2[['age', 'bmi', 'charges']]

corcol.corr(method='pearson').style.format("{:.2}").background_gradient(cmap
=plot.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_6423adf4_c79c_11e8_bf91_8aa7e1d632fdrow0_col0 {
#             background-color:  #b40426;
#         }    #T_6423adf4_c79c_11e8_bf91_8aa7e1d632fdrow0_col1 {
#             background-color:  #3b4cc0;
#         }    #T_6423adf4_c79c_11e8_bf91_8aa7e1d632fdrow0_col2 {
#             background-color:  #80a3fa;
#         }    #T_6423adf4_c79c_11e8_bf91_8aa7e1d632fdrow1_col0 {
#             background-color:  #3b4cc0;
#         }    #T_6423adf4_c79c_11e8_bf91_8aa7e1d632fdrow1_col1 {
#             background-color:  #b40426;
#         }    #T_6423adf4_c79c_11e8_bf91_8aa7e1d632fdrow1_col2 {
#             background-color:  #5977e3;
#         }    #T_6423adf4_c79c_11e8_bf91_8aa7e1d632fdrow2_col0 {
#             background-color:  #6282ea;
#         }    #T_6423adf4_c79c_11e8_bf91_8aa7e1d632fdrow2_col1 {
#             background-color:  #3b4cc0;
#         }    #T_6423adf4_c79c_11e8_bf91_8aa7e1d632fdrow2_col2 {
#             background-color:  #b40426;
# ...

# %%
corcol.corr(method='spearman').style.format("{:.2}").background_gradient(cmap
=plot.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_6429b280_c79c_11e8_bf91_8aa7e1d632fdrow0_col0 {
#             background-color:  #b40426;
#         }    #T_6429b280_c79c_11e8_bf91_8aa7e1d632fdrow0_col1 {
#             background-color:  #3b4cc0;
#         }    #T_6429b280_c79c_11e8_bf91_8aa7e1d632fdrow0_col2 {
#             background-color:  #d7dce3;
#         }    #T_6429b280_c79c_11e8_bf91_8aa7e1d632fdrow1_col0 {
#             background-color:  #3b4cc0;
#         }    #T_6429b280_c79c_11e8_bf91_8aa7e1d632fdrow1_col1 {
#             background-color:  #b40426;
#         }    #T_6429b280_c79c_11e8_bf91_8aa7e1d632fdrow1_col2 {
#             background-color:  #3e51c5;
#         }    #T_6429b280_c79c_11e8_bf91_8aa7e1d632fdrow2_col0 {
#             background-color:  #d5dbe5;
#         }    #T_6429b280_c79c_11e8_bf91_8aa7e1d632fdrow2_col1 {
#             background-color:  #3b4cc0;
#         }    #T_6429b280_c79c_11e8_bf91_8aa7e1d632fdrow2_col2 {
#             background-color:  #b40426;
# ...
